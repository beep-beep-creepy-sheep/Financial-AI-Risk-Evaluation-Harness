# %% [markdown]
# # Evaluation Walkthrough
#
# This lightweight notebook documents the intended offline workflow. The project does not depend on notebooks.
#
# ```bash
# fin-ai-risk-eval run-all
# ```
#
# Review generated artifacts in `data/` and `reports/`.
